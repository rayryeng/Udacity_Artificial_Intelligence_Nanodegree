# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = (16, 12)

# %%
noe_acp1 = [43, 21, 60, 7, 6, 6, 6, 50, 28, 43, 33]
noe_acp2 = [3343, 624, 5154, 17, 9, 27, 9, 2467, 357, 2887, 1037]
noe_acp3 = [14663, 408, 18510, 25, 14, 21, 35, 7388, 369, 9580, 3423]
noe_acp4 = [99736, 25174, 113339, 29, 17, 56, 107, 34330, 1208, 62077, 22606]
matr = np.array([noe_acp1, noe_acp2, noe_acp3, noe_acp4]).T
index = ['20', '72', '88', '104']
algos = ['breadth_first_search', 'depth_first_graph_search', 'uniform_cost_search', 'greedy_best_first_graph_search with h_unmet_goals',
        'greedy_best_first_graph_search with h_pg_levelsum', 'greedy_best_first_graph_search with h_pg_maxlevel', 'greedy_best_first_graph_search with h_pg_setlevel',
        'astar_search with h_unmet_goals', 'astar_search with h_pg_levelsum', 'astar_search with h_pg_maxlevel', 'astar_search with h_pg_setlevel']
dct = {}
for (row, alg) in zip(matr, algos):
    dct[alg] = row
df = pd.DataFrame(dct, index=index)
ax = df.plot.bar(rot=0, logy=True, title='Number of expansions vs. Number of actions')
ax.set_xlabel('Number of actions')
_ = ax.set_ylabel('Number of expansions')

# %%
time_acp1 = [0.2563, 0.1013, 0.3548, 0.0156, 0.0156, 0.0057, 0.2184, 0.1039, 0.5516, 0.0016, 0.0145]
time_acp2 = [9.6307, 53.6832, 121.5738, 0.5644, 0.2765, 0.4504, 0.3678, 0.6354, 1.4267, 0.0009, 0.5452]
time_acp3 = [18.7543, 307.8437, 693.2235, 0.7893, 0.6969, 0.1465, 0.8634, 0.8361, 7.4406, 0.0138, 1.1093]
time_acp4 = [96.4861, 3159.5437, 7389.5437, 3.9654, 5.0149, 968.9437, 1.4156, 2.5663, 34.6134, 0.0237, 7.6457]
matr = np.array([time_acp1, time_acp2, time_acp3, time_acp4]).T
index = ['20', '72', '88', '104']
algos = ['breadth_first_search', 'depth_first_graph_search', 'uniform_cost_search', 'greedy_best_first_graph_search with h_unmet_goals',
        'greedy_best_first_graph_search with h_pg_levelsum', 'greedy_best_first_graph_search with h_pg_maxlevel', 'greedy_best_first_graph_search with h_pg_setlevel',
        'astar_search with h_unmet_goals', 'astar_search with h_pg_levelsum', 'astar_search with h_pg_maxlevel', 'astar_search with h_pg_setlevel']
dct = {}
for (row, alg) in zip(matr, algos):
    dct[alg] = row
df = pd.DataFrame(dct, index=index)
ax = df.plot.bar(rot=0, logy=True, title='Time of execution (s) vs. Number of actions')
ax.set_xlabel('Number of actions')
_ = ax.set_ylabel('Time of execution (s)')

# %%
pl_acp1 = [6, 20, 6, 6, 6, 6, 6, 6, 6, 6, 6]
pl_acp2 = [9, 619, 9, 9, 9, 9, 9, 9, 9, 9, 9]
pl_acp3 = [12, 392, 12, 15, 14, 13, 17, 12, 12, 12, 12]
pl_acp4 = [14, 24132, 14, 18, 17, 17, 23, 14, 15, 14, 14]
matr = np.array([pl_acp1, pl_acp2, pl_acp3, pl_acp4]).T
index = ['20', '72', '88', '104']
algos = ['breadth_first_search', 'depth_first_graph_search', 'uniform_cost_search', 'greedy_best_first_graph_search with h_unmet_goals',
        'greedy_best_first_graph_search with h_pg_levelsum', 'greedy_best_first_graph_search with h_pg_maxlevel', 'greedy_best_first_graph_search with h_pg_setlevel',
        'astar_search with h_unmet_goals', 'astar_search with h_pg_levelsum', 'astar_search with h_pg_maxlevel', 'astar_search with h_pg_setlevel']
dct = {}
for (row, alg) in zip(matr, algos):
    dct[alg] = row
df = pd.DataFrame(dct, index=index)
ax = df.plot.bar(rot=0, logy=True, title='Plan length vs. Number of actions')
ax.set_xlabel('Number of actions')
_ = ax.set_ylabel('Plan length')
